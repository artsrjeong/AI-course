# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage
llm = ChatOllama(model="gemma4:e2b", base_url="http://127.0.0.1:11434")

llm.invoke([HumanMessage("잘 지냈어?")])
# Out:
# AIMessage(content='응, 잘 지냈어! 너는 잘 지냈어? 😊', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-22T06:37:52.7119106Z', 'done': True, 'done_reason': 'stop', 'total_duration': 28187061500, 'load_duration': 24893092700, 'prompt_eval_count': 21, 'prompt_eval_duration': 153741000, 'eval_count': 289, 'eval_duration': 3135562000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0c7d5-5ea9-7ce0-9776-423a5f6fac9f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 289, 'total_tokens': 310})

# %%
from langchain_core.tools import tool
from datetime import datetime
import pytz

@tool # @tool 데코레이터를 사용하여 함수를 도구로 등록
def get_current_time(timezone: str, location: str) -> str:
    """ 현재 시각을 반환하는 함수

    Args:
        timezone (str): 타임존 (예: 'Asia/Seoul') 실제 존재하는 타임존이어야 함
        location (str): 지역명. 타임존이 모든 지명에 대응되지 않기 때문에 이후 llm 답변 생성에 사용됨
    """
    tz = pytz.timezone(timezone)
    now = datetime.now(tz).strftime("%Y-%m-%d %H:%M:%S")
    location_and_local_time = f'{timezone} ({location}) 현재시각 {now} ' # 타임존, 지역명, 현재시각을 문자열로 반환
    print(location_and_local_time)
    return location_and_local_time

# %%
# 도구를 tools 리스트에 추가하고, tool_dict에도 추가
tools = [get_current_time,]
tool_dict = {"get_current_time": get_current_time,}

# 도구를 모델에 바인딩: 모델에 도구를 바인딩하면, 도구를 사용하여 llm 답변을 생성할 수 있음
llm_with_tools = llm.bind_tools(tools)

# %%
from langchain_core.messages import SystemMessage

# (4) 사용자의 질문과 tools 사용하여 llm 답변 생성
messages = [
    SystemMessage("너는 사용자의 질문에 답변을 하기 위해 tools를 사용할 수 있다."),
    HumanMessage("부산은 지금 몇시야?"),
]

# (5) llm_with_tools를 사용하여 사용자의 질문에 대한 llm 답변 생성
response = llm_with_tools.invoke(messages)
messages.append(response)

# (6) 생성된 llm 답변 출력
print(messages)
# Out:
# [SystemMessage(content='너는 사용자의 질문에 답변을 하기 위해 tools를 사용할 수 있다.', additional_kwargs={}, response_metadata={}), HumanMessage(content='부산은 지금 몇시야?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-22T06:38:04.3106145Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3890889900, 'load_duration': 7462800, 'prompt_eval_count': 157, 'prompt_eval_duration': 824630000, 'eval_count': 309, 'eval_duration': 3046378000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0c7d5-eae1-7312-8075-349b39472ea4-0', tool_calls=[{'name': 'get_current_time', 'args': {'location': 'Busan', 'timezone': 'Asia/Seoul'}, 'id': 'c23f4b66-46c3-44ae-87aa-b346bbb0cb72', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 157, 'output_tokens': 309, 'total_tokens': 466})]

# %%
for tool_call in response.tool_calls:
    selected_tool = tool_dict[tool_call["name"]] # (7) tool_dict를 사용하여 도구 함수를 선택
    print(tool_call["args"]) # (8) 도구 호출 시 전달된 인자 출력
    tool_msg = selected_tool.invoke(tool_call) # (9) 도구 함수를 호출하여 결과를 반환
    messages.append(tool_msg)

messages
# Out:
# {'location': 'Busan', 'timezone': 'Asia/Seoul'}
# Asia/Seoul (Busan) 현재시각 2026-09-22 15:41:25
# [SystemMessage(content='너는 사용자의 질문에 답변을 하기 위해 tools를 사용할 수 있다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산은 지금 몇시야?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-22T06:38:04.3106145Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3890889900, 'load_duration': 7462800, 'prompt_eval_count': 157, 'prompt_eval_duration': 824630000, 'eval_count': 309, 'eval_duration': 3046378000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0c7d5-eae1-7312-8075-349b39472ea4-0', tool_calls=[{'name': 'get_current_time', 'args': {'location': 'Busan', 'timezone': 'Asia/Seoul'}, 'id': 'c23f4b66-46c3-44ae-87aa-b346bbb0cb72', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 157, 'output_tokens': 309, 'total_tokens': 466}),
#  ToolMessage(content='Asia/Seoul (Busan) 현재시각 2026-09-22 15:41:25 ', name='get_current_time', tool_call_id='c23f4b66-46c3-44ae-87aa-b346bbb0cb72')]

# %%
llm_with_tools.invoke(messages)
# Out:
# AIMessage(content='부산은 현재 **2026년 9월 22일 15시 41분 25초**입니다.', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-22T06:42:21.0475958Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1333593900, 'load_duration': 8149500, 'prompt_eval_count': 227, 'prompt_eval_duration': 431085000, 'eval_count': 92, 'eval_duration': 877541000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0c7d9-dfc0-7172-b6b4-450ab1aad2da-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 227, 'output_tokens': 92, 'total_tokens': 319})

# %%
from pydantic import BaseModel, Field

class StockHistoryInput(BaseModel):
    ticker: str = Field(..., title="주식 코드", description="주식 코드 (예: AAPL)")
    period: str = Field(..., title="기간", description="주식 데이터 조회 기간 (예: 1d, 1mo, 1y)")

# %%
import yfinance as yf

@tool
def get_yf_stock_history(stock_history_input: StockHistoryInput) -> str:
    """ 주식 종목의 가격 데이터를 조회하는 함수
    Args:
        stock_history_input.ticker: str = Field(..., title="주식 코드", description="주식 코드 (예: AAPL)")
        stock_history_input.period: str = Field(..., title="기간", description="주식 데이터 조회 기간 (예: 1d, 1mo, 1y)")
    """
    stock = yf.Ticker(stock_history_input.ticker)
    history = stock.history(period=stock_history_input.period)
    history_md = history.to_markdown() 

    return history_md

tools = [get_current_time, get_yf_stock_history]
tool_dict = {"get_current_time": get_current_time, "get_yf_stock_history": get_yf_stock_history}

llm_with_tools = llm.bind_tools(tools)

# %%
messages.append(HumanMessage("테슬라는 한달 전에 비해 주가가 올랐나 내렸나?"))

response = llm_with_tools.invoke(messages)
print(response)
messages.append(response)
# Out:
# content='' additional_kwargs={} response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-22T06:42:53.0816954Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5786212600, 'load_duration': 6748900, 'prompt_eval_count': 312, 'prompt_eval_duration': 482053000, 'eval_count': 534, 'eval_duration': 5279755000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'} id='lc_run--01a0c7da-4b7d-7271-bef0-2edeed040878-0' tool_calls=[{'name': 'get_yf_stock_history', 'args': {'stock_history_input': {'symbol': 'TSLA'}}, 'id': '016bf87b-f2bc-4f77-b2e1-f99306254f1a', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 312, 'output_tokens': 534, 'total_tokens': 846}

# %%
for tool_call in response.tool_calls:
    selected_tool = tool_dict[tool_call["name"]]
    print(tool_call["args"])
    tool_msg = selected_tool.invoke(tool_call)
    messages.append(tool_msg)
    print(tool_msg)
# Out:
# {'stock_history_input': {'symbol': 'TSLA'}}
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 4
#       2 selected_tool = tool_dict[tool_call["name"]]
#       3 print(tool_call["args"])
# ----> 4 tool_msg = selected_tool.invoke(tool_call)
#       5 messages.append(tool_msg)
#       6 print(tool_msg)
#
# File E:\Project\AI-course\.venv\Lib\site-packages\langchain_core\tools\base.py:764, in BaseTool.invoke(self, input, config, **kwargs)
#     756 @override
#     757 def invoke(
#     758     self,
#    (...)    761     **kwargs: Any,
#     762 ) -> Any:
#     763     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 764     return self.run(tool_input, **kwargs)
#
# File E:\Project\AI-course\.venv\Lib\site-packages\langchain_core\tools\base.py:1132, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1130 if error_to_raise:
#    1131     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1132     raise error_to_raise
#    1133 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1134 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File E:\Project\AI-course\.venv\Lib\site-packages\langchain_core\tools\base.py:1091, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1089 child_config = patch_config(config, callbacks=run_manager.get_child())
#    1090 with set_config_context(child_config) as context:
# -> 1091     tool_args, tool_kwargs = self._to_args_and_kwargs(
#    1092         tool_input, tool_call_id
#    1093     )
#    1094     if signature(self._run).parameters.get("run_manager"):
#    1095         tool_kwargs |= {"run_manager": run_manager}
#
# File E:\Project\AI-course\.venv\Lib\site-packages\langchain_core\tools\base.py:993, in BaseTool._to_args_and_kwargs(self, tool_input, tool_call_id)
#     985 if (
#     986     self.args_schema is not None
#     987     and isinstance(self.args_schema, type)
#    (...)    990 ):
#     991     # StructuredTool with no args
#     992     return (), {}
# --> 993 tool_input = self._parse_input(tool_input, tool_call_id)
#     994 # For backwards compatibility, if run_input is a string,
#     995 # pass as a positional argument.
#     996 if isinstance(tool_input, str):
#
# File E:\Project\AI-course\.venv\Lib\site-packages\langchain_core\tools\base.py:834, in BaseTool._parse_input(self, tool_input, tool_call_id)
#     832             raise ValueError(msg)
#     833         tool_input[k] = tool_call_id
# --> 834 result_v2 = input_args.model_validate(tool_input)
#     835 result_dict = result_v2.model_dump()
#     836 provided_fields = result_v2.model_fields_set
#
# File E:\Project\AI-course\.venv\Lib\site-packages\pydantic\main.py:732, in BaseModel.model_validate(cls, obj, strict, extra, from_attributes, context, by_alias, by_name)
#     726 if by_alias is False and by_name is not True:
#     727     raise PydanticUserError(
#     728         'At least one of `by_alias` or `by_name` must be set to True.',
#     729         code='validate-by-alias-and-name-false',
#     730     )
# --> 732 return cls.__pydantic_validator__.validate_python(
#     733     obj,
#     734     strict=strict,
#     735     extra=extra,
#     736     from_attributes=from_attributes,
#     737     context=context,
#     738     by_alias=by_alias,
#     739     by_name=by_name,
#     740 )
#
# ValidationError: 2 validation errors for get_yf_stock_history
# stock_history_input.ticker
#   Field required [type=missing, input_value={'symbol': 'TSLA'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
# stock_history_input.period
#   Field required [type=missing, input_value={'symbol': 'TSLA'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing

# %%
llm_with_tools.invoke(messages)
# Out:
# AIMessage(content='한 달 전인 2025년 1월 15일의 테슬라(TSLA) 주가는 428.22였고, 현재 주가는 355.84입니다. 따라서 테슬라 주가는 한 달 사이에 하락했습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 1642, 'total_tokens': 1698, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_13eed4fce1', 'finish_reason': 'stop', 'logprobs': None}, id='run-804353a9-2124-419a-b099-3c648b738ee8-0', usage_metadata={'input_tokens': 1642, 'output_tokens': 56, 'total_tokens': 1698, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
