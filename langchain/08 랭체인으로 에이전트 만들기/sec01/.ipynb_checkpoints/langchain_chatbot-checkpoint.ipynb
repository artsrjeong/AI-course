# %%
# %uv add langchain-ollama
# Out:
# Note: you may need to restart the kernel to use updated packages.
# E:\Project\AI-course\.venv\Scripts\python.exe: No module named uv

# %%
from langchain_ollama import ChatOllama
model = ChatOllama(model="gemma4:e2b", base_url="http://127.0.0.1:11434")

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="안녕? 나는 이성용이야.")])
# Out:
# AIMessage(content='안녕하세요, 이성용 님! 만나서 반갑습니다. 😊', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-18T09:54:43.5530651Z', 'done': True, 'done_reason': 'stop', 'total_duration': 70941074000, 'load_duration': 43009412300, 'prompt_eval_count': 25, 'prompt_eval_duration': 22146918000, 'eval_count': 14, 'eval_duration': 5776632000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0b3ef-7fbf-74b3-8fc9-6a056e89e3a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 25, 'output_tokens': 14, 'total_tokens': 39})

# %%
model.invoke([HumanMessage(content="내 이름이 뭐지?")])
# Out:
# AIMessage(content='죄송하지만 저는 사용자님의 이름을 알 수 없습니다. 이름을 말씀해 주시겠어요? 😊', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-09-18T09:54:46.7756334Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3210364200, 'load_duration': 5763300, 'prompt_eval_count': 22, 'prompt_eval_duration': 78787000, 'eval_count': 272, 'eval_duration': 3120606000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--01a0b3f0-94ec-78b0-af4c-24980aaa57a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 272, 'total_tokens': 294})
