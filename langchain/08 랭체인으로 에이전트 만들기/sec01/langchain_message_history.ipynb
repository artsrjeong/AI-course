# %%
from langchain_core.chat_history import InMemoryChatMessageHistory  # 메모리에 대화 기록을 저장하는 클래스
from langchain_core.runnables.history import RunnableWithMessageHistory  # 메시지 기록을 활용해 실행 가능한 래퍼wrapper 클래스
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

model = ChatOllama(model="gemma4:e2b", base_url="http://127.0.0.1:11434")


# 세션별 대화 기록을 저장할 딕셔너리
store = {}

# 세션 ID에 따라 대화 기록을 가져오는 함수
def get_session_history(session_id: str):
    # 만약 해당 세션 ID가 store에 없으면, 새로 생성해 추가함
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()  # 메모리에 대화 기록을 저장하는 객체 생성
    return store[session_id]  # 해당 세션의 대화 기록을 반환

# 모델 실행 시 대화 기록을 함께 전달하는 래퍼 객체 생성
with_message_history = RunnableWithMessageHistory(model, get_session_history)
# Out:
# E:\Project\AI-course\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3701: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
config = {"configurable": {"session_id": "abc2"}}  # 세션 ID를 설정하는 config 객체 생성

response = with_message_history.invoke(
    [HumanMessage(content="안녕? 난 이성용이야.")],
    config=config,
)

print(response.content)
# Out:
# 안녕하세요, 이성용님! 만나서 반갑습니다. 😊

# %%
response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 당신의 이름은 이성용입니다. 😊

# %%
config = {"configurable": {"session_id": "abc3"}}

response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

response.content
# Out:
# '죄송하지만, 저는 당신의 이름을 알 수 없습니다.\n\n당신의 이름을 알려주시겠어요?'

# %%
config = {"configurable": {"session_id": "abc2"}}

response = with_message_history.invoke(
    [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
    config=config,
)

response.content
# Out:
# '우리는 방금 인사하고 이름을 확인하는 내용만 나누었습니다.\n\n제가 "안녕하세요, 이성용님! 만나서 반갑습니다."라고 인사드렸고, 이어서 "당신의 이름은 이성용입니다."라고 확인해 드렸습니다.\n\n혹시 다른 주제로 이야기를 나누고 싶으신가요? 😊'

# %%
config = {"configurable": {"session_id": "abc2"}}
for r in with_message_history.stream(
    [HumanMessage(content = "내가 어느 나라 사람인지 맞춰보고, 그 나라의 문화에 대해 말해봐")],
    config=config,
):
    print(r.content, end="|")
# Out:
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||죄|송|하지만|,| 저는| 사용자|님|에| 대한| 개인|적인| 정보|나| 배경| 지|식이| 없|기| 때문에| 사용자|님이| 어느| 나라| 사람|인지| 맞|추|는| 것은| 불|가능|합니다|.| |😅|
#
# |하지만| 재미|있는| 게임|으로| 즐|기고| 싶|으|시|다면|,| **|혹|시| 어떤| 나라|에| 대해| 이야기|해| 보고| 싶|으|신|가|요|?|**| 원|하시는| 나라|를| 말씀|해| 주|시면|,| 제가| 그| 나라|의| 문화|와| 역사|에| 대해| 자세|히| 설명|해| 드릴|게요|!| 😊|||
