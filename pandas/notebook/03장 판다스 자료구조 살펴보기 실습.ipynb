# %% [markdown]
# ## 03-1 나만의 데이터 만들기

# %% [markdown]
# ### 시리즈와 데이터프레임 만들기

# %% [markdown]
# #### [Do It! 실습] 시리즈 만들기

# %%
import pandas as pd

s = pd.Series(['banana', 42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object
